# %%
import numpy as np
import pandas as pd

# %%
missing_data = ["na","n.a.","0"]
df = pd.read_csv("Nan.csv",na_values = missing_data)
df
# Out:
#    First Name  Gender    Salary   Bonus Senior Hanagement  \
# 0     Douglas    Male   97308.0   6.945              True
# 1      Thomas    Male   61933.0     NaN              True
# 2       Jerry    Male       NaN   9.340              True
# 3      Dennis     NaN  115163.0  10.125             False
# 4         NaN  Female       NaN  11.598               NaN
# 5      Angela     NaN       NaN  18.523              True
# 6       Shawn    Male  111737.0   6.414             False
# 7      Rachel  Female  142032.0  12.599             False
# 8       Linda  Female   57427.0   9.557              True
# 9   Stephanie  Female   36844.0   5.574              True
# 10        NaN     NaN       NaN     NaN               NaN
#
#                      Team
# 0               Marketing
# 1                     NaN
# 2                 Finance
# 3                   Legal
# 4                 Finance
# 5             Engineering
# 6                     NaN
# 7    Business Development
# ...

# %%
taitanic = pd.read_csv("titanic.csv")


#specific columns from DF
ages = taitanic["Age"].shape
print(type(taitanic["Age"]))
# Out:
# <class 'pandas.core.series.Series'>
